# %% [markdown]
# d-sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px">
# </div>

# %% [markdown]
# # Applied Principal Components Analysis
#
# **Objective**: *Demonstrate the use of Principal Components Analysis on a dataset.*
#
# In this demo, we will complete a series of exercises to perform PCA on a dataset and interpret the results.

# %%
# %run "../../Includes/Classroom-Setup"
# Out:
# Mounting course-specific datasets to <b>/mnt/training</b>...</br>Datasets are already mounted to <b>/mnt/training</b> from <b>s3a://databricks-corp-training/common</b>
# Out[2]: DataFrame[]
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res1: Boolean = false
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res2: Boolean = false
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res3: Boolean = false
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ## Prepare data
#
# In this demo, we're going to prepare our data to a user-level table again, but we're going to add some more aggregations and some interacted features in the process. This will help us see the impact of reducing our feature space using PCA.

# %%
# %sql
CREATE OR REPLACE TABLE adsda.ht_user_metrics_pca
USING DELTA LOCATION "/adsda/ht-user-metrics-pca" AS (
  SELECT min(resting_heartrate) AS min_resting_heartrate,
         avg(resting_heartrate) AS avg_resting_heartrate,
         max(resting_heartrate) AS max_resting_heartrate,
         min(active_heartrate) AS min_active_heartrate,
         avg(active_heartrate) AS avg_active_heartrate,
         max(active_heartrate) AS max_active_heartrate,
         min(bmi) AS min_bmi,
         avg(bmi) AS avg_bmi,
         max(bmi) AS max_bmi,
         min(vo2) AS min_vo2,
         avg(vo2) AS avg_vo2,
         max(vo2) AS max_vo2,
         min(workout_minutes) AS min_workout_minutes,
         avg(workout_minutes) AS avg_workout_minutes,
         max(workout_minutes) AS max_workout_minutes,
         min(steps) AS min_steps,
         avg(steps) AS avg_steps,
         max(steps) AS max_steps,
         avg(steps) * avg(active_heartrate) AS as_x_aah,
         max(bmi) - min(bmi) AS bmi_change
  FROM adsda.ht_daily_metrics
  GROUP BY device_id
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# If we display this table, we'll see there are a lot more features in our table than we had in previous demos.

# %%
# %sql
SELECT * FROM adsda.ht_user_metrics_pca LIMIT 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>min_resting_heartrate</th><th>avg_resting_heartrate</th><th>max_resting_heartrate</th><th>min_active_heartrate</th><th>avg_active_heartrate</th><th>max_active_heartrate</th><th>min_bmi</th><th>avg_bmi</th><th>max_bmi</th><th>min_vo2</th><th>avg_vo2</th><th>max_vo2</th><th>min_workout_minutes</th><th>avg_workout_minutes</th><th>max_workout_minutes</th><th>min_steps</th><th>avg_steps</th><th>max_steps</th><th>as_x_aah</th><th>bmi_change</th></tr></thead><tbody><tr><td>100.12190323385116</td><td>82.68379727873081</td><td>99.13828099149359</td><td>120.30779135992243</td><td>139.43487473206162</td><td>162.34782728523246</td><td>19.530815683202114</td><td>22.398063650890794</td><td>24.997081438324194</td><td>20.28334129074003</td><td>20.99401157735923</td><td>21.491176274984294</td><td>1.0469302273257908</td><td>5.5026324666656405</td><td>9.325750004894761</td><td>2539</td><td>5171.495890410959</td><td>7837</td><td>721086.8816568236</td><td>5.46626575512208</td></tr><tr><td>52.71287564903336</td><td>77.73294228506452</td><td>97.93773119202254</td><td>109.04938651327842</td><td>127.05715346661702</td><td>146.86986814834722</td><td>22.63526877190205</td><td>25.150812654086298</td><td>27.93361433865782</td><td>24.929150796942785</td><td>25.52747526955064</td><td>26.231702127031934</td><td>12.109056090051782</td><td>37.2167018100805</td><td>66.11591853237638</td><td>10027</td><td>7115.591780821917</td><td>9611</td><td>904086.8369016891</td><td>5.298345566755767</td></tr><tr><td>100.37366097806768</td><td>86.51162895591307</td><td>99.78933645583436</td><td>129.5517281106538</td><td>147.31573126952208</td><td>177.78314996951866</td><td>16.84474064400951</td><td>19.148256000462478</td><td>21.339664540140973</td><td>18.81713072211899</td><td>19.448406520026342</td><td>19.946846814093323</td><td>10.524606159589158</td><td>45.00008651086257</td><td>84.72505622254651</td><td>10822</td><td>7257.693150684931</td><td>9909</td><td>1069172.3738229524</td><td>4.494923896131464</td></tr><tr><td>58.41880559722201</td><td>77.55054135762612</td><td>98.87532936858241</td><td>110.84551702943472</td><td>129.5770039396946</td><td>146.7386499653505</td><td>21.33582041108623</td><td>24.240375728856797</td><td>26.909149799032416</td><td>20.705859570960108</td><td>21.40130178285617</td><td>22.088526447872425</td><td>11.402530422658407</td><td>37.886068725488464</td><td>68.11952462786931</td><td>10014</td><td>7129.690410958904</td><td>9864</td><td>923843.9224696248</td><td>5.573329387946185</td></tr><tr><td>49.81689070901131</td><td>68.93310580458204</td><td>92.68678860925904</td><td>116.68894230853843</td><td>136.50268661405897</td><td>162.3638297702582</td><td>27.4860355505171</td><td>30.726595797380472</td><td>33.87217279937333</td><td>28.102425066324887</td><td>28.855230169253637</td><td>29.7652881606717</td><td>11.659988588325357</td><td>32.24198398599063</td><td>60.51374198315488</td><td>10317</td><td>6958.378082191781</td><td>9766</td><td>949837.3026955613</td><td>6.38613724885623</td></tr><tr><td>47.35569868189229</td><td>69.31244794850774</td><td>92.76249605385787</td><td>147.8761660158842</td><td>167.18585016710105</td><td>186.28361490243202</td><td>23.589288180958636</td><td>27.1326690342849</td><td>31.02646723458486</td><td>30.032977706533124</td><td>30.939205114246853</td><td>32.02682828439313</td><td>0.8561243193074577</td><td>5.119426899323105</td><td>9.947677458057841</td><td>2938</td><td>5128.024657534246</td><td>7310</td><td>857333.1620477202</td><td>7.437179053626224</td></tr><tr><td>43.51461112051503</td><td>64.64397544858174</td><td>82.07381856112256</td><td>126.14263661366581</td><td>152.9654977304546</td><td>173.98748183735378</td><td>25.865189192070154</td><td>29.17716498363452</td><td>32.82229405815375</td><td>27.834198767673833</td><td>28.92795344089978</td><td>29.78220180035955</td><td>0.800631665598566</td><td>5.01508 ...

# %% [markdown]
# -sandbox
# ## PCA
#
# ### Training Process
# When we perform PCA in Python, we again want our data in a Pandas DataFrame.
#
# Then, we can take advantage of `sklearn`'s `PCA` class to easily perform the reduction.
#
# <img alt="Side Note" title="Side Note" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.05em; transform:rotate(15deg)" src="https://files.training.databricks.com/static/images/icon-note.webp"/> Rememeber that we need to scale our features for PCA.

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale

df = spark.table("adsda.ht_user_metrics_pca").toPandas()
pca = PCA(random_state=42)
pca.fit(scale(df))
# Out:
# Out[8]: PCA(random_state=42)

# %% [markdown]
# Notice that we didn't set very many hyperparameters – options that we can use to control the training process.
#
# As a result, a lot of the defaults are set, including the number of components:

# %%
pca.n_components_
# Out:
# Out[9]: 20

# %% [markdown]
# This is equal to the number of features in our DataFrame, but remember: we likely only need to use a few.

# %% [markdown]
# ### Variance Explained
#
# Remember that PCA attempts to explain as much of the variance in the input features with as few of components as possible.
#
# To see how effective this was, we can look at the percent of variance explained by each of our components.

# %%
pca.explained_variance_ratio_
# Out:
# Out[10]: array([5.18843155e-01, 1.93032114e-01, 1.12509960e-01, 4.45854883e-02,
#        4.06366380e-02, 3.29549658e-02, 1.50554466e-02, 9.84673023e-03,
#        7.80463726e-03, 6.87076180e-03, 5.93412188e-03, 4.35902306e-03,
#        4.12363688e-03, 2.13863828e-03, 1.12364723e-03, 1.04019548e-04,
#        5.65488117e-05, 1.55497544e-05, 4.91691828e-06, 1.89931264e-33])

# %% [markdown]
# While getting these values in an array can be helpful programmatically, it's helpful to visualize them directly.

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.bar(range(1, 21), pca.explained_variance_ratio_) 
plt.xlabel('Component') 
plt.xticks(range(1, 21))
plt.ylabel('Percent of variance explained')
plt.ylim(0, 1)
plt.yticks(np.arange(0, 1, step=0.1))
plt.show()

# %% [markdown]
# As you can see, the initial few components capture the majority of the variance in our 20 original features.
#
# To see just how much, it can be helpful to plot this as the cumulative sum of variance explained.

# %%
plt.plot(range(1, 21), np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Component') 
plt.xticks(range(1, 21))
plt.ylabel('Percent of cumulative variance explained')
plt.ylim(0, 1)
plt.yticks(np.arange(0, 1, step=0.1))
plt.show()

# %% [markdown]
# We can now easily see that the first three components account for over 80 percent of the variation in our data.
#
# Through the rest of this lesson, we'll look at how we can use the results of our PCA process on real-world data science projects.

# %% [markdown]
# -sandbox
# &copy; 2020 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>
