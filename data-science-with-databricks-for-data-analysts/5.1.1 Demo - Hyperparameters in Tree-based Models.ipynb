# %% [markdown]
# d-sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px">
# </div>

# %% [markdown]
# # Hyperparameters in Tree-based Models
#
# **Objective**: *Demonstrate the manual process of changing hyperparameters and testing values.*
#
# In this demo, we will complete a series of exercises to explore the use of hyperparameters.

# %%
# %run "../../Includes/Classroom-Setup"
# Out:
# Mounting course-specific datasets to <b>/mnt/training</b>...</br>Datasets are already mounted to <b>/mnt/training</b> from <b>s3a://databricks-corp-training/common</b>
# Out[2]: DataFrame[]
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res1: Boolean = false
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res2: Boolean = false
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res3: Boolean = false
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ## Prepare data
#
# In this demo, we'll create an **`adsda.ht_user_metrics`** table. This table will be at the user-level.
#
# We'll alse be adding a new binary column **`steps_10000`** indicating whether or not the individual takes an average of at least 10,000 steps per day (`1` for yes, `0` for no).

# %%
# %sql
CREATE OR REPLACE TABLE adsda.ht_user_metrics
USING DELTA LOCATION "/adsda/ht-user-metrics" AS (
  SELECT avg(metrics.resting_heartrate) AS avg_resting_heartrate,
         avg(metrics.active_heartrate) AS avg_active_heartrate,
         avg(metrics.bmi) AS avg_bmi,
         avg(metrics.vo2) AS avg_vo2,
         avg(metrics.workout_minutes) AS avg_workout_minutes,
         CASE WHEN avg(metrics.steps) >= 10000 THEN 1 ELSE 0 END AS steps_10000
  FROM adsda.ht_daily_metrics metrics
  INNER JOIN adsda.ht_users users ON metrics.device_id = users.device_id
  GROUP BY metrics.device_id, users.lifestyle
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# We can display our new table and confirm our **`steps_10000`** column.

# %%
# %sql
SELECT * FROM adsda.ht_user_metrics LIMIT 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>avg_resting_heartrate</th><th>avg_active_heartrate</th><th>avg_bmi</th><th>avg_vo2</th><th>avg_workout_minutes</th><th>steps_10000</th></tr></thead><tbody><tr><td>54.0284328440395</td><td>108.28615934932891</td><td>12.654053882785398</td><td>33.03972742973578</td><td>49.85972670403038</td><td>1</td></tr><tr><td>54.77908266525594</td><td>108.15071784658238</td><td>20.91366854373003</td><td>36.50039642145559</td><td>32.38710983013407</td><td>1</td></tr><tr><td>82.71709277672224</td><td>123.75660244868575</td><td>21.775089958039707</td><td>18.609142842404506</td><td>40.607693444622576</td><td>1</td></tr><tr><td>54.65683212557368</td><td>110.26062426718684</td><td>10.975399291225694</td><td>29.183789361817826</td><td>53.622766046330945</td><td>1</td></tr><tr><td>81.1145477254848</td><td>131.062285127167</td><td>22.33872524194543</td><td>24.338430651153843</td><td>5.7806587919834</td><td>0</td></tr><tr><td>49.121654377406905</td><td>116.95658221162829</td><td>23.873621520980663</td><td>41.20961725020616</td><td>44.92626070562924</td><td>1</td></tr><tr><td>54.77494950167725</td><td>128.54677955505105</td><td>22.100005515666016</td><td>35.79725405982539</td><td>48.14001371848655</td><td>1</td></tr><tr><td>74.70086634248925</td><td>121.67227153993254</td><td>28.792669925300466</td><td>25.805953355652942</td><td>34.87085859794914</td><td>0</td></tr><tr><td>82.23193357821977</td><td>138.53324585681642</td><td>24.707027023043285</td><td>20.56033559557636</td><td>36.731238237383536</td><td>0</td></tr><tr><td>96.05237605034688</td><td>147.66059236683043</td><td>17.117911573521425</td><td>15.281249859214014</td><td>49.09652773997195</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# ### Train-test Split
#
# Remember that we need to split our training data and our test data so we can determine whether or not our models generalize well.

# %%
from sklearn.model_selection import train_test_split

ht_user_metrics_pd_df = spark.table("adsda.ht_user_metrics").toPandas()

train_df, test_df = train_test_split(ht_user_metrics_pd_df, train_size=0.8, test_size=0.2, random_state=42)

# %% [markdown]
# ## Random Forest
#
# In this demo, we'll try to build a random forest to predict whether each user takes 10,000 steps per day.
#
# ### Hyperparameters
#
# We'll focus on two hyperparameters:
#
# 1. `max_depth` - the maximum depth of each tree
# 2. `n_estimators` – the number of trees in the forest

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier(random_state=42)

# %% [markdown]
# Let's take a look at our current values for each of these hyperparameters.

# %%
rfc.get_params()
# Out:
# Out[10]: {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 42,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# These aren't the hyperparameters we want. Let's change them.

# %%
rfc.set_params(max_depth=2, n_estimators=3)
# Out:
# Out[11]: RandomForestClassifier(max_depth=2, n_estimators=3, random_state=42)

# %% [markdown]
# And we can verify that we changed the hyperparameters.

# %%
rfc.get_params()
# Out:
# Out[12]: {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': 2,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 3,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 42,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# ### Train and Evaluate Model
#
# Now that we've set our hyperparameters to our preferred values, let's train and evaluate our model using accuracy.

# %%
from sklearn.metrics import accuracy_score

# Fit the model
rfc.fit(train_df.drop("steps_10000", axis=1), train_df["steps_10000"])

# Train accuracy
train_accuracy = accuracy_score(
  train_df["steps_10000"], 
  rfc.predict(train_df.drop("steps_10000", axis=1))
)

# Test accuracy
test_accuracy = accuracy_score(
  test_df["steps_10000"], 
  rfc.predict(test_df.drop("steps_10000", axis=1))
)
print("Train accuracy:", train_accuracy)
print("Test accuracy:", test_accuracy)
# Out:
# Train accuracy: 0.8891666666666667
# Test accuracy: 0.86

# %% [markdown]
# Given our pretty small forest and really shallow trees, we're seeing that we're slightly underfitting our training set.

# %% [markdown]
# ### New Hyperparameter Values
# Let's change our hyperparameter values to see if we can get a better accuracy.

# %%
rfc.set_params(max_depth=5, n_estimators=10)
# Out:
# Out[14]: RandomForestClassifier(max_depth=5, n_estimators=10, random_state=42)

# %%
# Fit the model
rfc.fit(train_df.drop("steps_10000", axis=1), train_df["steps_10000"])

# Train accuracy
train_accuracy = accuracy_score(
  train_df["steps_10000"], 
  rfc.predict(train_df.drop("steps_10000", axis=1))
)

# Test accuracy
test_accuracy = accuracy_score(
  test_df["steps_10000"], 
  rfc.predict(test_df.drop("steps_10000", axis=1))
)
print("Train accuracy:", train_accuracy)
print("Test accuracy:", test_accuracy)
# Out:
# Train accuracy: 0.9191666666666667
# Test accuracy: 0.8683333333333333

# %% [markdown]
# That's a little better.

# %% [markdown]
# ### One More Time
#
# Let's try one more time.

# %%
rfc.set_params(max_depth=8, n_estimators=100)

# Fit the model
rfc.fit(train_df.drop("steps_10000", axis=1), train_df["steps_10000"])

# Train accuracy
train_accuracy = accuracy_score(
  train_df["steps_10000"], 
  rfc.predict(train_df.drop("steps_10000", axis=1))
)

# Test accuracy
test_accuracy = accuracy_score(
  test_df["steps_10000"], 
  rfc.predict(test_df.drop("steps_10000", axis=1))
)
print("Train accuracy:", train_accuracy)
print("Test accuracy:", test_accuracy)
# Out:
# Train accuracy: 0.9475
# Test accuracy: 0.88

# %% [markdown]
# And that's even better! Hopefully it's clear how changing the hyperparameter values can affect the training process and, as a result, the performance of the model.
#
# **Question:** How could we determine the optimal values for our hyperparameters?

# %% [markdown]
# Through the rest of this lesson, we'll look at how to optimize these values.

# %% [markdown]
# -sandbox
# &copy; 2020 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>
