# %% [markdown]
# d-sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px">
# </div>

# %% [markdown]
# # Applied K-means Clustering
#
# **Objective**: *Demonstrate how to perform K-means clustering using Python and sklearn.*
#
# In this demo, we will complete a series of exercises to practice performing K-means clustering analyses.

# %%
# %run "../../Includes/Classroom-Setup"
# Out:
# Mounting course-specific datasets to <b>/mnt/training</b>...</br>Datasets are already mounted to <b>/mnt/training</b> from <b>s3a://databricks-corp-training/common</b>
# Out[2]: DataFrame[]
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res1: Boolean = false
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res2: Boolean = false
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res3: Boolean = false
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# -sandbox
#
# ## Prepare data
#
# ### Aggregate our user-level table
#
# Remember we are interested in a user-level clustering based on our project objective. As a result, we'll recreate our **`adsda.ht_user_metrics`** table from the previous demo.
#
# <img alt="Side Note" title="Side Note" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.05em; transform:rotate(15deg)" src="https://files.training.databricks.com/static/images/icon-note.webp"/> We are removing the **`lifestyle`** and **`device_id`** columns from this analysis because K-means clustering requires all feature variables to be numeric.

# %%
# %sql
CREATE OR REPLACE TABLE adsda.ht_user_metrics
USING DELTA LOCATION "/adsda/ht-user-metrics" AS (
  SELECT avg(resting_heartrate) AS avg_resting_heartrate,
         avg(active_heartrate) AS avg_active_heartrate,
         avg(bmi) AS avg_bmi,
         avg(vo2) AS avg_vo2,
         avg(workout_minutes) AS avg_workout_minutes,
         avg(steps) AS steps
  FROM adsda.ht_daily_metrics
  GROUP BY device_id
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# And we can visualize the result.

# %%
# %sql
SELECT * FROM adsda.ht_user_metrics LIMIT 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>avg_resting_heartrate</th><th>avg_active_heartrate</th><th>avg_bmi</th><th>avg_vo2</th><th>avg_workout_minutes</th><th>steps</th></tr></thead><tbody><tr><td>73.84670492514974</td><td>141.7665518846971</td><td>25.972345531696856</td><td>30.314501989400497</td><td>35.606040834647395</td><td>7007.131506849315</td></tr><tr><td>66.65136141242354</td><td>147.19021975989776</td><td>28.65722391606316</td><td>26.331489109483055</td><td>4.933198514612545</td><td>5222.191780821918</td></tr><tr><td>61.535264221129054</td><td>115.35464938159883</td><td>28.069176174299653</td><td>30.505853565396492</td><td>26.80897921409271</td><td>11651.545205479451</td></tr><tr><td>60.12761602451012</td><td>109.56012470925296</td><td>24.272346749436057</td><td>33.00945987357762</td><td>30.203698416630907</td><td>12232.284931506849</td></tr><tr><td>57.67928187578235</td><td>107.34804493259925</td><td>26.13666783325289</td><td>33.622191930293454</td><td>41.92978275902913</td><td>10685.441095890412</td></tr><tr><td>61.254321931199726</td><td>124.84391666265059</td><td>24.675104593153517</td><td>32.24746097933756</td><td>41.34549212923959</td><td>10838.29315068493</td></tr><tr><td>59.123912011085615</td><td>121.6281244436266</td><td>26.215711176682024</td><td>33.23270077091007</td><td>38.055842131738046</td><td>7065.627397260274</td></tr><tr><td>59.16707870402215</td><td>116.63147065007492</td><td>23.407247625285702</td><td>32.46844382359828</td><td>29.13189427605095</td><td>12333.975342465754</td></tr><tr><td>51.09170520840786</td><td>100.52788927517386</td><td>18.986985488002624</td><td>36.84238854947035</td><td>36.64032984626558</td><td>13517.109589041096</td></tr><tr><td>54.801011028249995</td><td>106.12513976241605</td><td>12.015741781532324</td><td>32.37704612619004</td><td>50.81642676699068</td><td>15935.090410958905</td></tr></tbody></table></div>

# %% [markdown]
# -sandbox
# ### Split data
#
# Next, we are going to split our table into a training set and inference set.
#
# <img alt="Side Note" title="Side Note" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.05em; transform:rotate(15deg)" src="https://files.training.databricks.com/static/images/icon-note.webp"/> In unsupervised learning, we do not perform label-based evaluation like we do in supervised learning. We are going to use the inference set as an example for assigning rows that were not a part of the training process to clusters.

# %%
from sklearn.model_selection import train_test_split

ht_user_metrics_pd_df = spark.table("adsda.ht_user_metrics").toPandas()

train_df, inference_df = train_test_split(ht_user_metrics_pd_df, train_size=0.9, test_size=0.1, random_state=42)

# %% [markdown]
# Note that the resulting DataFrames have the same number of columns, but they have a different number of rows.

# %%
train_df.shape
# Out:
# Out[9]: (2700, 6)

# %%
inference_df.shape
# Out:
# Out[10]: (300, 6)

# %% [markdown]
# -sandbox
# ## K-means
#
# ### Training
# Now, we can apply the K-means algorithm to our **`train_df`** DataFrame.
#
# Remember that in order to do this, we need to manually specify *K* ahead of the training process to the `num_clusters` parameter.
#
# <img alt="Side Note" title="Side Note" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.05em; transform:rotate(15deg)" src="https://files.training.databricks.com/static/images/icon-note.webp"/> We need to scale our feature variables because the K-means algorithm treats all features as if they're on the same scale. We'll go into more detail on this with more advanced tools in the next module.

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import scale

k_means = KMeans(n_clusters=4, random_state=42)
k_means.fit(scale(train_df))
# Out:
# Out[11]: KMeans(n_clusters=4, random_state=42)

# %% [markdown]
# #### Other Parameters
#
# There are plenty of other parameters to the K-means process, including:
#
# * `init` - how the initial centroids are determined
# * `max_iter` - how many iterations of the algorithm (i.e. how many times the centroids are reset)

# %% [markdown]
# #### Getting Centroids
#
# Once the model has been fit, the centroid locations can be extracted using the `cluster_centers_` attribute.

# %%
k_means.cluster_centers_
# Out:
# Out[12]: array([[-0.81628809, -0.82771227, -0.65713427,  0.82717395,  0.40978552,
#          0.86157681],
#        [ 1.49007169,  1.07097812, -0.00256275, -1.36179705,  0.35708406,
#         -0.94146452],
#        [-0.0254251 ,  0.18963867,  0.97138668, -0.10461086,  0.02524379,
#         -0.22271996],
#        [ 1.34192461,  1.43713671,  0.18521438, -1.22722739, -2.38117604,
#         -1.68906728]])

# %% [markdown]
# -sandbox
# <img alt="Side Note" title="Side Note" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.05em; transform:rotate(15deg)" src="https://files.training.databricks.com/static/images/icon-note.webp"/> Note that each of these array elements corresponds to a point, and the nested elements are the locations of each centroid for the various features used.

# %% [markdown]
# -sandbox
# ### Inference
#
# Once we've trained our K-means model, we can use the final cluster centroids to place new, unseen rows into clusters, as well.
#
# <img alt="Side Note" title="Side Note" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.05em; transform:rotate(15deg)" src="https://files.training.databricks.com/static/images/icon-note.webp"/> We are scaling our inference set, too. There are more advanced tools that can do this in an unbiased way, and we'll go over them in the next module.

# %%
inference_df_clusters = k_means.predict(scale(inference_df))

# %% [markdown]
# Notice that the output is a numpy array of the same length as **`inference_df`** DataFrame. This is because we returned a cluster for each one of our rows.

# %%
type(inference_df_clusters)
# Out:
# Out[14]: numpy.ndarray

# %%
len(inference_df_clusters)
# Out:
# Out[15]: 300

# %% [markdown]
# Since we have a numpy array of the same length, we can bind the array with **`inference_df`** into a new DataFrame.

# %%
clusters_df = inference_df.copy()
clusters_df["cluster"] = inference_df_clusters

# %% [markdown]
# So we can easily view the cluster of each row.

# %%
display(clusters_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>avg_resting_heartrate</th><th>avg_active_heartrate</th><th>avg_bmi</th><th>avg_vo2</th><th>avg_workout_minutes</th><th>steps</th><th>cluster</th></tr></thead><tbody><tr><td>51.26632775279057</td><td>105.93233389251066</td><td>16.473336965670203</td><td>36.61798456931176</td><td>40.7040080285147</td><td>14107.542465753424</td><td>0</td></tr><tr><td>53.36949895580931</td><td>105.13342668907612</td><td>15.266639373950296</td><td>30.50197298862535</td><td>61.723381727310944</td><td>12528.257534246575</td><td>0</td></tr><tr><td>86.51162895591307</td><td>147.31573126952208</td><td>19.148256000462478</td><td>19.448406520026342</td><td>45.00008651086257</td><td>7257.693150684931</td><td>1</td></tr><tr><td>62.67832822341962</td><td>126.55070760439426</td><td>28.538456483092702</td><td>30.136315631288845</td><td>36.31521454706571</td><td>10320.065753424658</td><td>2</td></tr><tr><td>78.3843123177059</td><td>144.53044270305998</td><td>23.844876989899003</td><td>26.163978233651594</td><td>5.414068675377703</td><td>5161.969863013699</td><td>3</td></tr><tr><td>88.77611148763101</td><td>141.08416692979114</td><td>19.766028414343424</td><td>17.78960369105766</td><td>44.186527980857164</td><td>7320.213698630137</td><td>1</td></tr><tr><td>57.27612483145937</td><td>111.60339113286958</td><td>23.145380588746512</td><td>35.686557410414416</td><td>31.522302178442793</td><td>12780.506849315068</td><td>0</td></tr><tr><td>70.70788585271985</td><td>126.2168310858353</td><td>29.521241718275274</td><td>27.893232976180293</td><td>34.27955417018405</td><td>7003.47397260274</td><td>2</td></tr><tr><td>60.792963094367806</td><td>112.31210378465445</td><td>26.230405518542675</td><td>33.26614809274604</td><td>38.53207307447889</td><td>7152.268493150685</td><td>2</td></tr><tr><td>64.43306557874654</td><td>138.60789599559456</td><td>32.12179645298689</td><td>31.69966046250843</td><td>32.93655042544162</td><td>6827.219178082192</td><td>2</td></tr><tr><td>51.34105837116899</td><td>97.08068115721477</td><td>20.17356794107809</td><td>37.15524731223913</td><td>35.75776953728754</td><td>13613.315068493152</td><td>0</td></tr><tr><td>80.79791341761526</td><td>140.41920920273523</td><td>24.377772371866218</td><td>23.69856039873388</td><td>5.254346159903993</td><td>5186.704109589041</td><td>3</td></tr><tr><td>61.08799741812013</td><td>127.81763933942916</td><td>33.15155797829772</td><td>30.32555623676971</td><td>33.21967326992338</td><td>10061.142465753424</td><td>2</td></tr><tr><td>76.03140197754537</td><td>136.11322364381357</td><td>23.63034957920583</td><td>25.25984374359101</td><td>5.724817161093259</td><td>5132.791780821918</td><td>3</td></tr><tr><td>57.09841706831352</td><td>128.2647892266181</td><td>21.77856168485237</td><td>37.10722691864296</td><td>45.131727823813755</td><td>11084.438356164384</td><td>0</td></tr><tr><td>61.42131995568504</td><td>114.40213969472232</td><td>27.292849068198624</td><td>31.087084209597474</td><td>26.940142451237893</td><td>11774.08493150685</td><td>2</td></tr><tr><td>48.41618817173116</td><td>88.22759468736619</td><td>23.203467548797533</td><td>43.695812508287965</td><td>30.998778292933267</td><td>12487.967123287672</td><td>0</td></tr><tr><td>88.25367872075994</td><td>144.0201331411336</td><td>18.59389847751982</td><td>19.910217746151737</td><td>46.565626768309755</td><td>7367.52602739726</td><td>1</td></tr><tr><td>72.4635987011015</td><td>129.63198705862848</td><td>25.57846400820064</td><td>24.504775967164136</td><td>36.87616760484349</td><td>7149.28493150685</td><td>1</td></tr><tr><td>49.967661780666056</td><td>106.97315163847558</td><td>21.56662442613395</td><td>39.82743650586012</td><td>34.96209380251127</td><td>13155.66301369863</td><td>0</td></tr><tr><td>61.51804542764749</td><td>130.18468174164695</td><td>27.53789211469144</td><td>30.508931970137994</td><td>37.689519940163585</td><td>7217.293150684932</td><td>2< ...

# %% [markdown]
# Through the rest of this lesson, we'll look at optimizing the use of the K-means algorithm.

# %% [markdown]
# -sandbox
# &copy; 2020 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>
